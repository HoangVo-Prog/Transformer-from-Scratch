# %%
from Data.data import cache_or_process
from config import sos_token, eos_token, pad_token

_, validation_loader, _, en_tokenizer, vi_tokenizer = cache_or_process()
# Out:
# 🔄 Preprocessing and tokenizing datasets...
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/1268 [00:00<?, ? examples/s]

# %%
print(validation_loader.dataset[0]["src_ids"])
print(en_tokenizer.encode(validation_loader.dataset[0]["en"]).ids)

print(en_tokenizer.encode(sos_token).ids)
print(en_tokenizer.encode(eos_token).ids)
print(en_tokenizer.encode(pad_token).ids)
# Out:
# [0, 750, 40, 195, 480, 13, 40, 663, 254, 902, 195, 128, 979, 133, 128, 1230, 13, 145, 40, 2533, 275, 4497, 59, 2002, 608, 8, 192, 28, 6047, 1512, 3188, 6987, 15, 8, 192, 28, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# [750, 40, 195, 480, 13, 40, 663, 254, 902, 195, 128, 979, 133, 128, 1230, 13, 145, 40, 2533, 275, 4497, 59, 2002, 608, 8, 192, 28, 6047, 1512, 3188, 6987, 15, 8, 192, 28]
# [0]
# [1]
# [2]

# %%
print(validation_loader.dataset[1]["src_ids"])
print(validation_loader.dataset[2]["src_ids"])
print(validation_loader.dataset[3]["src_ids"])
print(validation_loader.dataset[4]["src_ids"])
print(validation_loader.dataset[5]["src_ids"])
print(validation_loader.dataset[6]["src_ids"])
print(validation_loader.dataset[7]["src_ids"])
print(validation_loader.dataset[8]["src_ids"])
# Out:
# [0, 180, 40, 195, 239, 3718, 15, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# [0, 392, 722, 13, 159, 1748, 59, 473, 146, 363, 3453, 128, 1312, 146, 9786, 19225, 14, 28757, 13, 280, 159, 717, 1389, 452, 243, 128, 1553, 361, 13, 2339, 152, 1535, 13, 2199, 6494, 13, 2314, 190, 128, 8792, 15, 1, 2, 2, 2, 2, 2, 2, 2, 2]
# [0, 8400, 40, 1220, 4887, 243, 128, 1553, 361, 13, 40, 663, 40, 333, 1279, 254, 1282, 455, 127, 2593, 6494, 13, 1374, 969, 2576, 1518, 15, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# [0, 750, 40, 195, 1580, 393, 524, 13, 40, 1093, 254, 456, 1203, 15028, 13, 280, 40, 663, 254, 455, 127, 2593, 6494, 195, 1998, 15, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# ...

# %%
for i in range(10, 20):
    print(validation_loader.dataset[i]["src_ids"])
    print(validation_loader.dataset[i]["trg_ids"])
# Out:
# [0, 377, 195, 128, 456, 363, 40, 1281, 152, 272, 127, 254, 902, 339, 3637, 15, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# [0, 649, 279, 246, 648, 380, 636, 252, 398, 354, 622, 892, 267, 252, 358, 350, 1230, 1920, 294, 454, 15, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# [0, 11154, 653, 13, 315, 40, 195, 2292, 1399, 59, 1330, 4089, 13, 40, 1093, 445, 3243, 152, 40, 215, 8, 147, 28, 78, 14657, 278, 254, 2311, 15, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# [0, 800, 1163, 513, 279, 13, 334, 252, 410, 524, 254, 423, 1898, 13, 252, 506, 366, 254, 969, 776, 602, 2063, 307, 252, 274, 651, 466, 255, 286, 1689, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# ...

# %%
print([1] + [2] + [1])
# Out:
# [1, 2, 1]
